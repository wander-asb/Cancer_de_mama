# %% [markdown]
# <a href="https://colab.research.google.com/github/wander-asb/Cancer_de_mama/blob/main/Cancer_mama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection      import train_test_split

from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
#Lemos o caminho do arquivo salvo no drive
df_cancer =  pd.read_excel('/content/gdrive/MyDrive/Datasets/Cancer_mama/dataBinaryOutput .xlsx')
df_cancer.shape
# Out:
# (568, 31)

# %%
#Imprimimos as primeiras cinco linhas do dataframe
df_cancer.head()
# Out:
#    Target      x1     x2      x3     x4       x5       x6       x7       x8  \
# 0       0  12.360  18.54   79.01  466.7  0.08477  0.06815  0.02643  0.01921
# 1       1  14.860  23.21  100.40  671.4  0.10440  0.19800  0.16970  0.08878
# 2       0  10.170  14.88   64.55  311.9  0.11340  0.08061  0.01084  0.01290
# 3       0  14.040  15.98   89.78  611.2  0.08458  0.05895  0.03534  0.02944
# 4       0   8.878  15.49   56.74  241.0  0.08293  0.07698  0.04721  0.02381
#
#        x9  ...     x21    x22     x23    x24     x25      x26      x27  \
# 0  0.1602  ...  13.290  27.49   85.56  544.1  0.1184  0.19630  0.19370
# 1  0.1737  ...  16.080  27.78  118.60  784.7  0.1316  0.46480  0.45890
# 2  0.2743  ...  11.020  17.45   69.86  368.6  0.1275  0.09866  0.02168
# 3  0.1714  ...  15.660  21.58  101.20  750.0  0.1195  0.12520  0.11170
# 4  0.1930  ...   9.981  17.70   65.27  302.0  0.1015  0.12480  0.09441
#
#        x28     x29      x30
# 0  0.08442  0.2983  0.07185
# ...

# %%
#Olhamos a estatística descritiva das features da tabela
df_cancer.describe().T
# Out:
#         count        mean         std         min         25%         50%  \
# Target  568.0    0.373239    0.484091    0.000000    0.000000    0.000000
# x1      568.0   14.131477    3.525739    6.981000   11.697500   13.375000
# x2      568.0   19.292694    4.304213    9.710000   16.170000   18.855000
# x3      568.0   91.997342   24.311007   43.790000   75.135000   86.290000
# x4      568.0  655.297535  352.089317  143.500000  420.175000  551.400000
# x5      568.0    0.096341    0.014069    0.052630    0.086290    0.095865
# x6      568.0    0.104354    0.052858    0.019380    0.064815    0.092525
# x7      568.0    0.088863    0.079776    0.000000    0.029540    0.061545
# x8      568.0    0.048927    0.038837    0.000000    0.020310    0.033455
# x9      568.0    0.181199    0.027424    0.106000    0.161975    0.179250
# x10     568.0    0.062791    0.007065    0.049960    0.057697    0.061515
# x11     568.0    0.405114    0.277554    0.111500    0.232375    0.323950
# ...

# %%
df_cancer['Target'].value_counts()
# Out:
# 0    356
# 1    212
# Name: Target, dtype: int64

# %%
x = df_cancer.drop('Target', axis = 1)
Y = df_cancer['Target']

# %%
#Separação dos dados de treino, validação e teste
X_treino, X_teste, Y_treino, Y_teste = train_test_split(x, Y, test_size = 0.15, random_state=42)

#Tamos de cada base de separação
print(X_treino.shape, X_teste.shape, Y_treino.shape, Y_teste.shape)
# Out:
# (482, 30) (86, 30) (482,) (86,)

# %%
#Puxar modelos para serem baselines do dataframe em específico
